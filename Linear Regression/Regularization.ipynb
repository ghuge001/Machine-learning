# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\cars.csv2.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
df.replace("?",np.nan, inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
si = SimpleImputer()

df.iloc[:,[1,11]]= si.fit_transform(df.iloc[:,[1,11]])
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#      horsepower  city-mpg  highway-mpg  price
# 0         111.0        21           27  13495
# 1         111.0        21           27  16500
# 2         154.0        19           26  16500
# 3         102.0        24           30  13950
# 4         115.0        18           22  17450
# ..          ...       ...          ...    ...
# 200       114.0        23           28  16845
# 201       160.0        19           25  19045
# 202       134.0        18           23  21485
# 203       106.0        26           27  22470
# 204       114.0        19           25  22625
#
# [205 rows x 15 columns]

# %%
cat_cols = df.select_dtypes(object)
cat_cols
# Out:
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          4wd           front
# ..           ...       ...          ...          ...             ...
# 200        volvo       gas        sedan          rwd           front
# 201        volvo       gas        sedan          rwd           front
# 202        volvo       gas        sedan          rwd           front
# 203        volvo    diesel        sedan          rwd           front
# 204        volvo       gas        sedan          rwd           front
#
#     engine-type
# 0          dohc
# 1          dohc
# 2          ohcv
# 3           ohc
# 4           ohc
# ..          ...
# 200         ohc
# 201         ohc
# 202        ohcv
# 203         ohc
# 204         ohc
#
# [205 rows x 6 columns]

# %%
cat_cols = df.select_dtypes(object).columns
cat_cols
# Out:
# Index(['make', 'fuel-type', 'body-style', 'drive-wheels', 'engine-location',
#        'engine-type'],
#       dtype='object')

# %%
oe = OrdinalEncoder()

df[cat_cols] = oe.fit_transform(df[cat_cols])
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              122.0   0.0        1.0         0.0           2.0
# 1            3              122.0   0.0        1.0         0.0           2.0
# 2            1              122.0   0.0        1.0         2.0           2.0
# 3            2              164.0   1.0        1.0         3.0           1.0
# 4            2              164.0   1.0        1.0         3.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0  21.0        1.0         3.0           2.0
# 201         -1               95.0  21.0        1.0         3.0           2.0
# 202         -1               95.0  21.0        1.0         3.0           2.0
# 203         -1               95.0  21.0        0.0         3.0           2.0
# 204         -1               95.0  21.0        1.0         3.0           2.0
#
#      engine-location  width  height  engine-type  engine-size  horsepower  \
# 0                0.0   64.1    48.8          0.0          130       111.0
# 1                0.0   64.1    48.8          0.0          130       111.0
# 2                0.0   65.5    52.4          5.0          152       154.0
# 3                0.0   66.2    54.3          3.0          109       102.0
# 4                0.0   66.4    54.3          3.0          136       115.0
# ..               ...    ...     ...          ...          ...         ...
# 200              0.0   68.9    55.5          3.0          141       114.0
# 201              0.0   68.8    55.5          3.0          141       160.0
# 202              0.0   68.9    55.5          5.0          173       134.0
# 203              0.0   68.9    55.5          3.0          145       106.0
# 204              0.0   68.9    55.5          3.0          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 200        23           28  16845
# 201        19           25  19045
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625
#
# [205 rows x 15 columns]

# %%
x = df.iloc[:,:-1]
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=0.2,random_state=1)

# %%
lr = LinearRegression()
lr.fit(xtrain,ytrain)
ypred = lr.predict(xtest)

print(f"Train Accuracy is {lr.score(xtrain,ytrain) }\nTest Accuracy is {lr.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.8539412613914049
# Test Accuracy is 0.7440263258545703

# %%
lr.coef_
# Out:
# array([ 8.10627829e+01, -4.98250716e+00, -1.93628369e+02, -3.96939528e+02,
#        -1.59308387e+02,  2.03453658e+03,  1.61641371e+04,  8.12358117e+02,
#         2.86594382e+02,  3.04469374e+02,  9.72915986e+01, -1.24843308e+01,
#         2.37997595e+02, -3.56739524e+02])

# %% [markdown]
# # Lasso

# %%
l1 = Lasso(alpha=1)
l1.fit(xtrain,ytrain)

print(f"Train Accuracy is {l1.score(xtrain,ytrain) }\nTest Accuracy is {l1.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.8539398244720608
# Test Accuracy is 0.7442680796367557

# %%
l1.coef_
# Out:
# array([ 8.10099235e+01, -4.98244205e+00, -1.93459787e+02, -3.89872260e+02,
#        -1.60587747e+02,  2.03168757e+03,  1.60855755e+04,  8.10235442e+02,
#         2.87249208e+02,  3.04384733e+02,  9.73692186e+01, -1.23519330e+01,
#         2.36917278e+02, -3.55445582e+02])

# %% [markdown]
# # Hyperparameter Tuning

# %%
for i in range(100,200):
    l1 = Lasso(alpha=i)
    l1.fit(xtrain,ytrain)
    
    print(f"{i} {l1.score(xtrain,ytrain) } {l1.score(xtest,ytest)}")
# Out:
# 100 0.8399550254990269 0.7644150726044208
# 101 0.839676506856495 0.7645910215883893
# 102 0.8393951129870749 0.7647659882285329
# 103 0.839111060376169 0.7649401532453526
# 104 0.8388242397338375 0.765113425074071
# 105 0.8385345349342123 0.7652857085507104
# 106 0.8382421762634074 0.765457192795463
# 107 0.8379470482259248 0.765627782667494
# 108 0.8376490295547678 0.7657973803678715
# 109 0.8373483618984794 0.7659661812330157
# 110 0.8370449238236125 0.7661340868339704
# 111 0.8367385890666819 0.7663009968898453
# 112 0.8364296146136766 0.766467115971018
# 113 0.8361177485059506 0.7666322443886756
# 114 0.835803243772388 0.7667965815573101
# 115 0.8354858300186775 0.7669599153505949
# 116 0.8351657814298427 0.7671224598759209
# 117 0.8348428153561449 0.7672839955065132
# 118 0.8345172182613105 0.7674447438786605
# 119 0.8341887040017568 0.7676044846703385
# 120 0.833857568140685 0.7677634444292691
# 121 0.8335235110835549 0.7679213945163482
# 122 0.8331868353897823 0.7680785647942538
# 123 0.8328472300944721 0.768234720050474
# 124 0.8325050132398907 0.7683900998288435
# 125 0.8321598658436502 0.7685444648832087
# 126 0.8318121110259297 0.7686980565133965
# 127 0.8314614189430389 0.7688506294034283
# 128 0.8311081249368945 0.7690024319226847
# 129 0.830751888451875 0.7691532128509123
# 130 0.8303930623265703 0.769303231381959
# 131 0.8300312975699928 0.7694522320540775
# 132 0.8296669407592039 0.7696004674524938
# 133 0.8292996341498704 0.7697476778085559
# 134 0.8289295541958841 0.7698939914994923
# 135 0.8285568932056011 0.7700395463298336
# 136 0.8281812733640992 0.7701840710565171
# 137 0.8278028808219656 0.770327699564358
# 138 0.8274217158128865 0.7704704320196865
# 139 0.8270379859714487 0.7706124150583678
# 140 0.8266512830609837 0.7707533598387855
# 141 0.826261808598699 0.7708934091782005
# 142 0.8258695642921344 0.7710325642629068
# 143 0.825474769577696 0.7711709779054461
# 144 0.8250769887543985 0.7713083461104957
# 145 0.8246764380041747 0.7714448199404749
# 146 0.8242731178406684 0.7715803997327544
# 147 0.8238670288304109 0.7717150858568789
# 148 0.8234581715970458 0.7718488787170117
# 149 0.8230465467312356 0.7719817786899409
# 150 0.8226321544747063 0.7721137859105283
# 151 0.8222152484003333 0.7722450724036388
# 152 0.8217950727308212 0.7723751253161617
# 153 0.821372385114234 0.7725044586836463
# 154 0.8209469343924909 0.7726329020349424
# 155 0.8205187217270196 0.772760456095513
# 156 0.8200877483821903 0.7728871216516281
# 157 0.819654015733016 0.7730128995547132
# 158 0.8192175252733814 0.7731377907259911
# 159 0.8187779906335211 0.7732616053993673
# 160 0.8183359901422183 0.7733847271140003
# 161 0.8178909393776682 0.7735067692205699
# 162 0.8174434417548806 0.773628129576754
# 163 0.8169928859423531 0.7737484060023355
# 164 0.8165399028019769 0.7738680120905652
# 165 0.8160838066003581 0.773986499345273
# 166 0.8156249548025752 0.7741041017816233
# 167 0.8151633624590349 0.7742208290560417
# 168 0.8146990388110401 0.7743366869701344
# 169 0.8142320961689135 0.7744517476841887
# 170 0.813762160321102 0.7745657699036099
# 171 0.8132895748074118 0.7746789749631495
# 172 0.8128143852048073 0.7747913913784678
# 173 0.8123359123999286 0.7749025850269149
# 174 0.8118550145392152 0.7750131037205223
# 175 0.8113715449305817 0.7751228488022203
# 176 0.8108848477369703 0.7752313488411905
# 177 0.810398027912919 0.7753376305711426
# 178 0.8099158018643546 0.7754478182455513
# 179 0.8094293509613448 0.7755604872007463
# 180 0.8089522112088928 0.7756633512238562
# 181 0.8084745716650823 0.7757692197002906
# 182 0.8079937860511277 0.7758755691448509
# 183 0.8075094384915956 0.7759820493662805
# 184 0.8070226130969378 0.7760874938213442
# 185 0.8065338733732969 0.7761911484092058
# 186 0.8060424845967608 0.7762938974357994
# 187 0.8055484467673292 0.7763957409011257
# 188 0.805051759885002 0.7764966788051844
# 189 0.8045524239497794 0.7765967111479755
# 190 0.8040504389616616 0.7766958379294989
# 191 0.8035458049206485 0.776794059149755
# 192 0.8030385218267397 0.7768913748087429
# 193 0.802528011426202 0.7769885911089182
# 194 0.8020154278048236 0.7770841030702453
# 195 0.8015001951364913 0.7771787094763879
# 196 0.8009823129490374 0.7772724086649718
# 197 0.8004617812977746 0.7773651852678701
# 198 0.7999386005905045 0.7774570563051003
# 199 0.7994127708272276 0.7775480217766628

# %%
l1 = Lasso(alpha=170)
l1.fit(xtrain,ytrain)
print(f"Train Accuracy is {l1.score(xtrain,ytrain) }\nTest Accuracy is {l1.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.813762160321102
# Test Accuracy is 0.7745657699036099

# %%
l1.coef_
# Out:
# array([  60.86342542,   -4.67935898, -166.24940597,   -0.        ,
#        -388.55024442, 1450.52919529, 2581.73459694,  395.71452995,
#         385.81770791,  293.38871775,  110.21053106,   10.6255676 ,
#          11.88800894, -118.9056547 ])

# %% [markdown]
# # Ridge

# %%
l2 = Ridge()
l2.fit(xtrain,ytrain)

print(f"Train Accuracy is {l2.score(xtrain,ytrain) }\nTest Accuracy is {l2.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.8482674089811109
# Test Accuracy is 0.7597037544007507

# %%
for i in range(1,50):
    l2 = Ridge(alpha=i)
    l2.fit(xtrain,ytrain)
    print(f"{i} {l2.score(xtrain,ytrain) } {l2.score(xtest,ytest)}")
# Out:
# 1 0.8482674089811109 0.7597037544007507
# 2 0.8415619363937634 0.7655470158349816
# 3 0.8363951508249315 0.7685522366994494
# 4 0.8324610677838389 0.7703895039721607
# 5 0.8293863299288737 0.7716361765232884
# 6 0.8269124234824403 0.7725405637365281
# 7 0.8248693933233862 0.7732264194061073
# 8 0.8231441159269755 0.7737624277305335
# 9 0.82165935802416 0.7741899891455903
# 10 0.8203609531530248 0.7745357446711172
# 11 0.8192099407731407 0.7748177686083773
# 12 0.8181776487192546 0.7750488663114244
# 13 0.8172425389038228 0.7752384410630865
# 14 0.8163881323933202 0.7753936067841306
# 15 0.8156016116243241 0.7755198811711732
# 16 0.8148728578870452 0.7756216343440715
# 17 0.814193775120706 0.7757023891700179
# 18 0.8135578061085904 0.7757650283597382
# 19 0.8129595805313181 0.7758119410917476
# 20 0.8123946550311476 0.7758451292906464
# 21 0.8118593185518819 0.7758662862953726
# 22 0.8113504446953662 0.7758768561943045
# 23 0.8108653784189215 0.7758780793379445
# 24 0.8104018481402175 0.7758710277800906
# 25 0.8099578968650147 0.7758566332527804
# 26 0.8095318277154503 0.7758357095185247
# 27 0.8091221604720197 0.7758089704268607
# 28 0.808727596619764 0.7757770446457072
# 29 0.8083469910198297 0.7757404877876715
# 30 0.8079793287859487 0.7756997924729909
# 31 0.80762370628214 0.7756553967416568
# 32 0.8072793154077205 0.7756076911325873
# 33 0.8069454305227695 0.7755570246773846
# 34 0.8066213975084485 0.775503710003391
# 35 0.8063066245641622 0.7754480277005842
# 36 0.8060005744261101 0.7753902300760604
# 37 0.8057027577555932 0.7753305443959518
# 38 0.8054127274951413 0.7752691756959365
# 39 0.8051300740294459 0.7752063092267908
# 40 0.8048544210187941 0.7751421125896794
# 41 0.8045854217970484 0.7750767376065454
# 42 0.8043227562456461 0.7750103219633416
# 43 0.8040661280706745 0.7749429906577694
# 44 0.8038152624226409 0.7748748572780987
# 45 0.8035699038087363 0.7748060251356028
# 46 0.8033298142556797 0.7747365882696801
# 47 0.803094771688007 0.7746666323419399
# 48 0.8028645684922324 0.7745962354331799
# 49 0.8026390102419068 0.7745254687551884

# %%
l2 = Ridge(alpha=10)
l2.fit(xtrain,ytrain)

print(f"Train Accuracy is {l2.score(xtrain,ytrain) }\nTest Accuracy is {l2.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.8203609531530248
# Test Accuracy is 0.7745357446711172

# %% [markdown]
# # Elastic Net

# %%
en = ElasticNet()

en.fit(xtrain,ytrain)

print(f"Train Accuracy is {en.score(xtrain,ytrain) }\nTest Accuracy is {en.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.7969654339953137
# Test Accuracy is 0.7722146104160098
